# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna99-star/OpenCV-for-Python-Developers-using-google-colab/blob/master/Adaptive_thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('sudoku.png', 0)
from google.colab.patches import cv2_imshow 
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=558x563 at 0x7F0207771A20>

# %%
ret, thresh_basic = cv2.threshold(img, 70, 255, cv2.THRESH_BINARY)
from google.colab.patches import cv2_imshow 
cv2_imshow(thresh_basic)
# Out:
# <PIL.Image.Image image mode=L size=558x563 at 0x7F020770F9B0>

# %%
thresh_adapt = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 115, 1)
from google.colab.patches import cv2_imshow 
cv2_imshow(thresh_adapt)
# Out:
# <PIL.Image.Image image mode=L size=558x563 at 0x7F02056A9F98>
