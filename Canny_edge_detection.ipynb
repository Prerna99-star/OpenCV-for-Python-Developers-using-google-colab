# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna99-star/OpenCV-for-Python-Developers-using-google-colab/blob/master/Canny_edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('tomatoes.jpg', 1)
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
res, thresh = cv2.threshold(hsv[:,:,0], 25, 255, cv2.THRESH_BINARY_INV )
from google.colab.patches import cv2_imshow
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=753x500 at 0x7F1D83734BA8>

# %%
edges = cv2.Canny(img, 100, 70)
from google.colab.patches import cv2_imshow
cv2_imshow(edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=753x500 at 0x7F1D82E247B8>
