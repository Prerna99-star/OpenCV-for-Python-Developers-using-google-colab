# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna99-star/OpenCV-for-Python-Developers/blob/master/Image_types%26color_channels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
color = cv2.imread("butterfly.jpg", 1)
plt.imshow(color)
plt.show()
print(color.shape)
height, width, channel = color.shape
# Out:
# (356, 493, 3)

# %%
b,g,r = cv2.split(color)

rgb_split = np.empty([height, width*3,3], 'uint8')

rgb_split[:, 0:width] = cv2.merge([b,b,b])
rgb_split[:, width:width*2] = cv2.merge([g,g,g])
rgb_split[:, width*2:width*3] = cv2.merge([r,r,r])

plt.imshow(rgb_split)

# %%
hsv = cv2.cvtColor(color, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(hsv)
hsv_split = np.concatenate((hsv), axis = 1)
plt.imshow(hsv_split)

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()
