# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna99-star/OpenCV-for-Python-Developers-using-google-colab/blob/master/Template_Matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
template = cv2.imread('template.jpg', 0)
frame = cv2.imread('players.jpg', 0)
from google.colab.patches import cv2_imshow
cv2_imshow(frame)
cv2_imshow(template)
# Out:
# <PIL.Image.Image image mode=L size=544x363 at 0x7FB0CBCF4940>
# <PIL.Image.Image image mode=L size=56x48 at 0x7FB0CBCF4A20>

# %%
result = cv2.matchTemplate(frame, template, cv2.TM_CCOEFF_NORMED)

min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
print(max_val, max_loc)
cv2.circle(result, max_loc, 15, 255, 2)

from google.colab.patches import cv2_imshow
cv2_imshow(result)
# Out:
# 0.4659753739833832 (132, 243)
# <PIL.Image.Image image mode=L size=489x316 at 0x7FB0CBD10B38>
