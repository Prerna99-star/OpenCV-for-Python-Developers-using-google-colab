# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna99-star/OpenCV-for-Python-Developers/blob/master/scale_and_rotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
img = cv2.imread("players.jpg", 1)
plt.imshow(img)

# %%
#Scale
img_half = cv2.resize(img, (0,0), fx = 0.5, fy = 0.5)
img_stretch = cv2.resize(img, (600, 600))
img_stretch_near = cv2.resize(img, (600,600), interpolation = cv2.INTER_NEAREST)

# %%
plt.imshow(img_half)

# %%
plt.imshow(img_stretch)

# %%
plt.imshow(img_stretch_near)

# %%
#Rotation
M = cv2.getRotationMatrix2D((0.5,0.5), -30, 1)
rotated = cv2.warpAffine(img, M, (img.shape[1], img.shape[0]))
plt.imshow(rotated)
